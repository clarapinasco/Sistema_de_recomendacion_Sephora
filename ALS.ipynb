# %%
import pandas as pd

# %%
re1=pd.read_csv('data/reviews_0-250.csv')
re2=pd.read_csv('data/reviews_250-500.csv')
re3=pd.read_csv('data/reviews_500-750.csv')
re4=pd.read_csv('data/reviews_750-1250.csv')
re5=pd.read_csv('data/reviews_1250-end.csv')
# Out:
# C:\Users\Nicolas\AppData\Local\Temp/ipykernel_12432/99614358.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   re1=pd.read_csv('data/reviews_0-250.csv')
# C:\Users\Nicolas\AppData\Local\Temp/ipykernel_12432/99614358.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   re4=pd.read_csv('data/reviews_750-1250.csv')
# C:\Users\Nicolas\AppData\Local\Temp/ipykernel_12432/99614358.py:5: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   re5=pd.read_csv('data/reviews_1250-end.csv')

# %%
re5.shape
# Out:
# (49977, 19)

# %%
df=pd.concat([re1, re2, re3, re4, re5], ignore_index=True)

# %%
df=re5

# %%
df=df[['author_id','rating','product_id']]
df.head(10)
# Out:
#      author_id  rating product_id
# 0   1945004256       5    P379064
# 1   5478482359       3    P379064
# 2  29002209922       5    P379064
# 3   7391078463       5    P379064
# 4   1766313888       5    P379064
# 5   1532951999       5    P379064
# 6   2168991896       5    P379064
# 7   5240639417       5    P379064
# 8   1599604155       5    P379064
# 9  11792701494       5    P379064

# %% [markdown]
# ## Dispersión

# %% [markdown]
# En los problemas del mundo real, se espera que la matriz de utilidad sea muy dispersa, ya que cada usuario sólo puntua una pequeña fracción de artículos entre el vasto conjunto de opciones disponibles. El problema del arranque en frío puede surgir cuando se añade un nuevo usuario o un nuevo artículo, ya que ambos carecen de historial de valoraciones. La dispersión puede calcularse de la siguietne manera:

# %%
#!pip install pyspark

# %%
from pyspark.sql.functions import col, explode
from pyspark import SparkContext
from pyspark.sql import SparkSession

sc = SparkContext
spark = SparkSession.builder.appName('Recommendations').getOrCreate()

# %%
from pyspark.sql import SparkSession

# Detener la sesión de Spark si está activa
try:
    spark.stop()
except:
    pass

# Crear una nueva sesión de Spark con más memoria
spark = SparkSession.builder \
    .appName("ALSExample") \
    .config("spark.driver.memory", "8g") \
    .config("spark.executor.memory", "8g") \
    .getOrCreate()

# %%
from pyspark.sql.types import FloatType
df_spark = spark.createDataFrame(df)
df_spark = df_spark.withColumn('rating', df_spark['rating'].cast(FloatType()))
# Count the total number of ratings in the dataset
numerator = df_spark.select("rating").count()

# Count the number of distinct userIds and distinct movieIds
num_users = df_spark.select("author_id").distinct().count()
num_movies = df_spark.select("product_id").distinct().count()

# Set the denominator equal to the number of users multiplied by the number of movies
denominator = num_users * num_movies

# Divide the numerator by the denominator
sparsity = (1.0 - (numerator *1.0)/denominator)*100
print("The ratings dataframe is ", "%.2f" % sparsity + "% empty.")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12432/4005038782.py in <module>
#       3 df_spark = df_spark.withColumn('rating', df_spark['rating'].cast(FloatType()))
#       4 # Count the total number of ratings in the dataset
# ----> 5 numerator = df_spark.select("rating").count()
#       6
#       7 # Count the number of distinct userIds and distinct movieIds
#
# c:\Users\Nicolas\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\sql\dataframe.py in count(self)
#    1236         3
#    1237         """
# -> 1238         return int(self._jdf.count())
#    1239
#    1240     def collect(self) -> List[Row]:
#
# c:\Users\Nicolas\AppData\Local\Programs\Python\Python310\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import IntegerType
df_spark = df_spark.withColumn("author_id", df_spark["author_id"].cast(IntegerType()))
df_spark = df_spark.withColumn("rating", df_spark["rating"].cast(IntegerType()))
df_spark = df_spark.withColumn("product_id", df_spark["product_id"].cast(IntegerType()))

# %%
from pyspark.ml.recommendation import ALS

# Configurar el modelo ALS
als = ALS(
    maxIter=10, 
    regParam=0.1, 
    userCol="author_id", 
    itemCol="product_id", 
    ratingCol="rating",
    coldStartStrategy="drop"
)

# Entrenar el modelo ALS
model = als.fit(df_spark)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14084/1823721517.py in <module>
#      12
#      13 # Entrenar el modelo ALS
# ---> 14 model = als.fit(df_spark)
#
# c:\Users\Nicolas\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\ml\base.py in fit(self, dataset, params)
#     203                 return self.copy(params)._fit(dataset)
#     204             else:
# --> 205                 return self._fit(dataset)
#     206         else:
#     207             raise TypeError(
#
# c:\Users\Nicolas\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\ml\wrapper.py in _fit(self, dataset)
#     379
#     380     def _fit(self, dataset: DataFrame) -> JM:
# --> 381         java_model = self._fit_java(dataset)
#     382         model = self._create_model(java_model)
#     383         return self._copyValues(model)
#
# ...

# %%
#pip install implicit
# Out:
# ...
#
# ...
#      -------------------------------------- 748.6/748.6 KB 4.7 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nicolas\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nicolas\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nicolas\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nicolas\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nicolas\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nicolas\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nicolas\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
from scipy.sparse import csr_matrix
from implicit.als import AlternatingLeastSquares
sparse_matrix = csr_matrix((df_spark['rating'], (df_spark['author_id'], df_spark['product_id'])))
model = AlternatingLeastSquares(factors=190, regularization=0.01, iterations=10)
# Out:
# ---------------------------------------------------------------------------
# PySparkValueError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14084/1254560171.py in <module>
#       1 from scipy.sparse import csr_matrix
#       2 from implicit.als import AlternatingLeastSquares
# ----> 3 sparse_matrix = csr_matrix((df_spark['rating'], (df_spark['author_id'], df_spark['product_id'])))
#       4 model = AlternatingLeastSquares(factors=190, regularization=0.01, iterations=10)
#       5
#
# c:\Users\Nicolas\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\compressed.py in __init__(self, arg1, shape, dtype, copy)
#      36
#      37         elif isinstance(arg1, tuple):
# ---> 38             if isshape(arg1):
#      39                 # It's a tuple of matrix dimensions (M, N)
#      40                 # create empty matrix
#
# ...

# %%
from scipy.sparse import csr_matrix

# Convertir las columnas necesarias a tipo entero si no lo están aún
df_spark = df_spark.withColumn("author_id", df_spark["author_id"].cast(IntegerType()))
df_spark = df_spark.withColumn("rating", df_spark["rating"].cast(IntegerType()))
df_spark = df_spark.withColumn("product_id", df_spark["product_id"].cast(IntegerType()))

# Crear la matriz dispersa csr_matrix
row_indices = df_spark.select("author_id").rdd.flatMap(lambda x: x).collect()
col_indices = df_spark.select("product_id").rdd.flatMap(lambda x: x).collect()
data_values = df_spark.select("rating").rdd.flatMap(lambda x: x).collect()

sparse_matrix = csr_matrix((data_values, (row_indices, col_indices)))

# Verificar las dimensiones de la matriz dispersa
print("Dimensiones de la matriz dispersa:", sparse_matrix.shape)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14084/2261017120.py in <module>
#       7
#       8 # Crear la matriz dispersa csr_matrix
# ----> 9 row_indices = df_spark.select("author_id").rdd.flatMap(lambda x: x).collect()
#      10 col_indices = df_spark.select("product_id").rdd.flatMap(lambda x: x).collect()
#      11 data_values = df_spark.select("rating").rdd.flatMap(lambda x: x).collect()
#
# c:\Users\Nicolas\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\rdd.py in collect(self)
#    1831         with SCCallSiteSync(self.context):
#    1832             assert self.ctx._jvm is not None
# -> 1833             sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#    1834         return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#    1835
#
# ...
